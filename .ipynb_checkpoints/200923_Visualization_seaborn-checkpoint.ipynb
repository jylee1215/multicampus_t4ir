# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# seaborn 디폴트 설정 
sns.set()

# %%
train = pd.read_csv("data/titanic/train.csv")
test = pd.read_csv("data/titanic/test.csv")

# %%
train.shape
# Out:
# (891, 12)

# %%
train.describe(include = ["O"]) #object type describe
# Out:
#                                        Name   Sex  Ticket    Cabin Embarked
# count                                   891   891     891      204      889
# unique                                  891     2     681      147        3
# top     Kantor, Mrs. Sinai (Miriam Sternin)  male  347082  B96 B98        S
# freq                                      1   577       7        4      644

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
Survived = train[train["Survived"] == 1]
not_survived = train[train["Survived"] == 0]

# %%
Survived

sur = Survived["Survived"].count() / train["Survived"].count() * 100
dea = not_survived["Survived"].count() / train["Survived"].count() * 100

print("Survived : {} ({}%)".format(Survived["Survived"].count(), round(sur,1)))
print("Not Survived : {} ({}%)".format(not_survived["Survived"].count(), round(dea,1)))
print("Total  : {}".format(len(train)))
# Out:
# Survived : 342 (38.4%)
# Not Survived : 549 (61.6%)
# Total  : 891

# %%
train.groupby("Survived")["Pclass"].value_counts()
# Out:
# Survived  Pclass
# 0         3         372
#           2          97
#           1          80
# 1         1         136
#           3         119
#           2          87
# Name: Pclass, dtype: int64

# %%
train[["Pclass", "Survived"]].groupby("Pclass", as_index = False).mean()
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
#선그래프
train.groupby("Pclass").Survived.mean().plot(kind = "bar")

# %%
sns.barplot(x="Pclass", y = "Survived", data = train)

# %%
train.groupby("Sex").Survived.value_counts()
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
train[["Sex", "Survived"]].groupby("Sex").mean()
train[["Sex", "Survived"]].groupby("Sex",as_index = False).mean()
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
sns.barplot(x="Sex", y = "Survived", data = train)

# %%
# cross table
pd.crosstab(train["Pclass"], train["Sex"])
# Out:
# Sex     female  male
# Pclass
# 1           94   122
# 2           76   108
# 3          144   347

# %%
sns.factorplot("Sex", "Survived", hue = "Pclass", data = train, size = 6, asspect = 2)
# Out:
# /Users/elie/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/elie/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.factorplot("Pclass", "Survived", hue = "Sex", data = train)
# Out:
# /Users/elie/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot("Pclass", "Survived", hue = "Sex", col = "Embarked" ,data = train)
# Out:
# /Users/elie/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
train.groupby("Embarked").Survived.value_counts()
# Out:
# Embarked  Survived
# C         1            93
#           0            75
# Q         0            47
#           1            30
# S         0           427
#           1           217
# Name: Survived, dtype: int64

# %%
sns.barplot(x="Embarked", y = "Survived", data = train)

# %%
train.groupby("Parch").Survived.value_counts()
# Out:
# Parch  Survived
# 0      0           445
#        1           233
# 1      1            65
#        0            53
# 2      0            40
#        1            40
# 3      1             3
#        0             2
# 4      0             4
# 5      0             4
#        1             1
# 6      0             1
# Name: Survived, dtype: int64

# %%
sns.barplot(x="Parch", y = "Survived", data = train, ci = None)

# %%
# violin plot
sns.violinplot("Age", "Embarked", hue = "Survived", data = train)

# %%
fig = plt.figure(figsize = (15,5))
ax1 = fig.add_subplot(131) #1줄 3칸 첫 번째 
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)


sns.violinplot("Embarked", "Age", hue = "Survived", data = train, ax = ax1)
sns.violinplot("Pclass", "Age", hue = "Survived", data = train, ax = ax2)
sns.violinplot("Sex", "Age", hue = "Survived", data = train, ax = ax3)

# %%
total_survived = train[train.Survived == 1] 
total_not_survived = train[train.Survived == 0] 

male_survived = train[(train.Survived == 1) & (train.Sex == "male")] 
female_survived = train[(train.Survived == 1) & (train.Sex == "female")] 

male_not_survived = train[(train.Survived == 0) & (train.Sex == "male")] 
female_not_survived = train[(train.Survived == 0) & (train.Sex == "female")]

# %%
plt.figure(figsize = [15,5])
plt.subplot(111)
sns.distplot(total_survived["Age"].dropna().values, kde = False, 
             bins = range(0, 81,1), color = 'blue')
sns.distplot(total_not_survived["Age"].dropna().values, kde = False, 
             bins = range(0, 81,1), color = 'red', axlabel = "Age") 
#kde 밀집도 그래프

# %%
plt.figure(figsize = [15,5])
plt.subplot(121)
sns.distplot(female_survived["Age"].dropna().values, kde = False, 
             bins = range(0, 81,1), color = 'green', axlabel = "Female Age")
sns.distplot(female_not_survived["Age"].dropna().values, kde = False, 
             bins = range(0, 81,1), color = 'red', axlabel = "Female Age")
plt.subplot(122)
sns.distplot(male_survived["Age"].dropna().values, kde = False, 
             bins = range(0, 81,1), color = 'green', axlabel = "Female Age")
sns.distplot(male_not_survived["Age"].dropna().values, kde = False, 
             bins = range(0, 81,1), color = 'red', axlabel = "Female Age")
#kde 밀집도 그래프

# %%
train.info()
train.corr()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# ...

# %%
plt.figure(figsize = (10,10))
sns.heatmap(train.drop("PassengerId", axis = 1).corr(), square = True, annot =True, vmax = 0.6)
